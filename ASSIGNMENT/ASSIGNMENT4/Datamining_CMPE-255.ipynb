# %% [markdown]
# #End To End ML datapreparation using Databricks on Heart Disease Classification Dataset from Kaggle
#
# End To End ML datapreparation using Databricks on [Heart Disease Classification Dataset](https://www.kaggle.com/datasets/sumaiyatasmeem/heart-disease-classification-dataset) by **WILLIBRORDUS BAYU NOVA PRAMUDYA** on Kaggle.
#
#
# **About Dataset**
#
# **Context**
#
# Use this heart disease classification dataset to predict which patients are most likely to suffer from a heart disease in the near future using the features given.
#
# **Content**
#
# Data Dictionary
#
# age: Displays the age of the individual.
#
# sex: Displays the gender of the individual using the following format : 1 = male 0 = female
#
# cp- Chest-pain type: displays the type of chest-pain experienced by the individual using the following format : 0 = typical angina 1 = atypical angina 2 = non — anginal pain 3 = asymptotic
#
# trestbps- Resting Blood Pressure: displays the resting blood pressure value of an individual in mmHg (unit). anything above 130-140 is typically cause for concern.
#
# chol- Serum Cholestrol: displays the serum cholesterol in mg/dl (unit)
#
# fbs- Fasting Blood Sugar: compares the fasting blood sugar value of an individual with 120mg/dl. If fasting blood sugar > 120mg/dl then : 1 (true) else : 0 (false) '>126' mg/dL signals diabetes
#
# restecg- Resting ECG : displays resting electrocardiographic results 0 = normal 1 = having ST-T wave abnormality 2 = left ventricular hyperthrophy
#
# thalach- Max heart rate achieved : displays the max heart rate achieved by an individual.
#
# exang- Exercise induced angina : 1 = yes 0 = no
#
# oldpeak- ST depression induced by exercise relative to rest: displays the value which is an integer or float.
#
# slope- Slope of the peak exercise ST segment : 0 = upsloping: better heart rate with excercise (uncommon) 1 = flat: minimal change (typical healthy heart) 2 = downsloping: signs of unhealthy heart
#
# ca- Number of major vessels (0–3) colored by flourosopy : displays the value as integer or float.
#
# thal : Displays the thalassemia : 1,3 = normal 6 = fixed defect 7 = reversible defect: no proper blood movement when excercising
#
# target : Displays whether the individual is suffering from heart disease or not : 1 = yes 0 = no

# %% [markdown]
# ##Importing Libraries

# %%
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##Adding data

# %%
df1 = pd.read_csv("/dbfs/FileStore/shared_uploads/tanujareddy.maligireddy@sjsu.edu/heart_disease_classification_dataset.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[277]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>age</th>
#       <th>sex</th>
#       <th>cp</th>
#       <th>trestbps</th>
#       <th>chol</th>
#       <th>fbs</th>
#       <th>restecg</th>
#       <th>thalach</th>
#       <th>exang</th>
#       <th>oldpeak</th>
# ...

# %% [markdown]
# ##Data Visualization

# %%
df1.describe().T.style.background_gradient(cmap = 'Spectral')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[278]: </div>
# <style  type="text/css" >
# #T_4e4ea_row0_col0,#T_4e4ea_row0_col2,#T_4e4ea_row1_col0,#T_4e4ea_row2_col0,#T_4e4ea_row4_col1,#T_4e4ea_row4_col3,#T_4e4ea_row4_col4,#T_4e4ea_row4_col5,#T_4e4ea_row4_col6,#T_4e4ea_row4_col7,#T_4e4ea_row5_col0,#T_4e4ea_row6_col0,#T_4e4ea_row8_col0,#T_4e4ea_row9_col0,#T_4e4ea_row10_col0,#T_4e4ea_row11_col0,#T_4e4ea_row12_col0{
#             background-color:  #5e4fa2;
#             color:  #f1f1f1;
#         }#T_4e4ea_row0_col1{
#             background-color:  #dff299;
#             color:  #000000;
# ...

# %%
df1.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[279]: Index([&#39;Unnamed: 0&#39;, &#39;age&#39;, &#39;sex&#39;, &#39;cp&#39;, &#39;trestbps&#39;, &#39;chol&#39;, &#39;fbs&#39;, &#39;restecg&#39;,
#        &#39;thalach&#39;, &#39;exang&#39;, &#39;oldpeak&#39;, &#39;slope&#39;, &#39;ca&#39;, &#39;thal&#39;, &#39;target&#39;],
#       dtype=&#39;object&#39;)</div>

# %%
df1.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[280]: Unnamed: 0      int64
# age             int64
# sex            object
# cp              int64
# trestbps      float64
# chol          float64
# fbs             int64
# restecg         int64
# thalach       float64
# exang           int64
# oldpeak       float64
# slope           int64
# ca              int64
# thal            int64
# target         object
# dtype: object</div>

# %%
gender = (df1.sex == 'male').astype(bool).astype(int)
gender_td = df1
gender_td.sex = gender
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
goal = (df1.target == 'yes').astype(bool).astype(int)
goal_td = df1
goal_td.target = goal
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
goal_td
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[283]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>age</th>
#       <th>sex</th>
#       <th>cp</th>
#       <th>trestbps</th>
#       <th>chol</th>
#       <th>fbs</th>
#       <th>restecg</th>
#       <th>thalach</th>
#       <th>exang</th>
#       <th>oldpeak</th>
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

dimensions = (3, 4)
 
f, axes = plt.subplots(dimensions[0], dimensions[1], figsize=(25, 15))
axis_i, axis_j = 0, 0
for col in goal_td.columns:
    if col == 'target'or col == 'sex':
        continue # Box plots cannot be used on indicator variables
    sns.boxplot(x=goal, y=goal_td[col], ax=axes[axis_i, axis_j])
    axis_j += 1
    if axis_j == dimensions[1]:
        axis_i += 1
        axis_j = 0
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">IndexError</span>                                Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3451465560037533&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# ...

# %% [markdown]
# ##Data Preprocessing

# %%
train_data.isna().any()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[285]: age            False
# job            False
# marital        False
# education      False
# default        False
# housing        False
# loan           False
# contact        False
# month          False
# day_of_week    False
# duration       False
# campaign       False
# pdays          False
# previous       False
# poutcome       False
# y              False
# dtype: bool</div>

# %%
df1.fillna(value = 99.0,
          inplace = True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn.model_selection import train_test_split
 
train, test = train_test_split(df1, random_state=123)
X_train = train.drop(["target"], axis=1)
X_test = test.drop(["target"], axis=1)
y_train = train.target
y_test = test.target
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
X_train.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[288]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>age</th>
#       <th>sex</th>
#       <th>cp</th>
#       <th>trestbps</th>
#       <th>chol</th>
#       <th>fbs</th>
#       <th>restecg</th>
#       <th>thalach</th>
#       <th>exang</th>
#       <th>oldpeak</th>
# ...

# %% [markdown]
# ##Baseline Model

# %%
# !pip install mlflow
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: mlflow in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.8/site-packages (1.30.0)
# ...
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.3 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/cluster_libraries/python/bin/python -m pip install --upgrade pip&#39; command.</span>
# </div>

# %%
import mlflow
import mlflow.pyfunc
import mlflow.sklearn
import numpy as np
mlflow.set_tracking_uri('databricks')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from mlflow.models.signature import infer_signature
 
class SklearnModelWrapper(mlflow.pyfunc.PythonModel):
    def __init__(self, model):
        self.model = model

    def predict(self, context, model_input):
        return self.model.predict_proba(model_input)[:,1]


with mlflow.start_run(run_name='untuned_random_forest'):
    n_estimators = 10
    model = RandomForestClassifier(n_estimators=n_estimators, random_state=np.random.RandomState(123))
    model.fit(X_train, y_train)


    predictions_test = model.predict_proba(X_test)[:,1]
    auc_score = roc_auc_score(y_test, predictions_test)
    mlflow.log_param('n_estimators', n_estimators)

    mlflow.log_metric('auc', auc_score)
    wrappedModel = SklearnModelWrapper(model)


    signature = infer_signature(X_train, wrappedModel.predict(None, X_train))
    mlflow.pyfunc.log_model("random_forest_model", python_model=wrappedModel, signature=signature)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ...

# %%
feature_importances = pd.DataFrame(model.feature_importances_, index=X_train.columns.tolist(), columns=['importance'])
feature_importances.sort_values('importance', ascending=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[292]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Unnamed: 0</th>
#       <td>0.412719</td>
#     </tr>
#     <tr>
#       <th>ca</th>
#       <td>0.154702</td>
#     </tr>
#     <tr>
#       <th>cp</th>
# ...

# %% [markdown]
# ##MLflow Model Registry

# %%
run_id = mlflow.search_runs(filter_string='tags.mlflow.runName = "untuned_random_forest"').iloc[0].run_id
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
model_name = "HeartDiseaseCheck"
model_version = mlflow.register_model(f"runs:/{run_id}/random_forest_model", model_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Successfully registered model &#39;HeartDiseaseCheck&#39;.
# 2022/11/03 09:54:57 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: HeartDiseaseCheck, version 1
# Created version &#39;1&#39; of model &#39;HeartDiseaseCheck&#39;.
# </div>

# %%
model_version
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[295]: &lt;ModelVersion: creation_timestamp=1667469297081, current_stage=&#39;None&#39;, description=&#39;&#39;, last_updated_timestamp=1667469299089, name=&#39;HeartDiseaseCheck&#39;, run_id=&#39;8964223da6614a658b25e265abe3ece8&#39;, run_link=&#39;&#39;, source=&#39;dbfs:/databricks/mlflow-tracking/1250308448975206/8964223da6614a658b25e265abe3ece8/artifacts/random_forest_model&#39;, status=&#39;READY&#39;, status_message=&#39;&#39;, tags={}, user_id=&#39;tanujareddy.maligireddy@sjsu.edu&#39;, version=&#39;1&#39;&gt;</div>

# %%
from mlflow.tracking import MlflowClient
 
client = MlflowClient()
client.transition_model_version_stage(
  name=model_name,
  version=model_version.version,
  stage="Production",
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[296]: &lt;ModelVersion: creation_timestamp=1667469297081, current_stage=&#39;Production&#39;, description=&#39;&#39;, last_updated_timestamp=1667469327585, name=&#39;HeartDiseaseCheck&#39;, run_id=&#39;8964223da6614a658b25e265abe3ece8&#39;, run_link=&#39;&#39;, source=&#39;dbfs:/databricks/mlflow-tracking/1250308448975206/8964223da6614a658b25e265abe3ece8/artifacts/random_forest_model&#39;, status=&#39;READY&#39;, status_message=&#39;&#39;, tags={}, user_id=&#39;2950089147083933&#39;, version=&#39;1&#39;&gt;</div>

# %%
best_run = mlflow.search_runs(order_by=['metrics.auc DESC']).iloc[0]
print(f'AUC of Best Run: {best_run["metrics.auc"]}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">AUC of Best Run: 0.9986139986139987
# </div>
